# %% [markdown]
# <a href="https://colab.research.google.com/github/fredprada/Python_for_Data_Science_and_AI_COURSE/blob/main/18_EXERCICIO_HTTP_and_Requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HTTP and Requests

# %% [markdown]
# When you, the **client**, use a web page your browser sends an **HTTP** request to the **server** where the page is hosted. The server tries to find the desired resource by default "index.html". If your request is successful, the server will send the object to the client in an **HTTP response**; this includes information like the type of the resource, the length of the resource, and other information.
#
# The figure below represents the process; the circle on the left represents the client, the circle on the right represents the Web server. The table under the Web server represents a list of resources stored in the web server. In this case an HTML file, png image, and txt file .
#
# The HTTP protocol allows you to send and receive information through the web including webpages, images, and other web resources. In this lab, we will provide an overview of the Requests library for interacting with the HTTP  protocol.

# %%
import requests
import os 
from PIL import Image
from IPython.display import IFrame

# %%
url='https://www.ibm.com/'
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=8C1DFAEBF34B9143153D62290BD10306~-1~~-1~-1~-1; bm_sz=4A9D084456779CBC3192D5C09E866A26~YAAQL6QFF/TLNMl3AQAAde8fywohgIftbNDHeWIoW9gPb51XfCsisqCMRs35m8QFI5HmUCEtDlEE2csM2p6CNIr50HMJKCS3n9hajL6sMq8O/N5FquJbFYw/ftwMTmwE/ugw+eCmcfOmgI8QtfvWJdP0CHwkFWbE1ClDwP6HS6xvr97yozl7qQQJT06f'}

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %%
header=r.headers
print(r.headers)
# Out:
# {'Server': 'Apache', 'x-drupal-dynamic-cache': 'UNCACHEABLE', 'Link': '<https://www.ibm.com/nl-en>; rel="canonical", <https://www.ibm.com/nl-en>; rel="revision", <https://www.ibm.com/nl-en>; rel="revision", <//1.cms.s81c.com>; rel=preconnect; crossorigin, <//1.cms.s81c.com>; rel=dns-prefetch', 'x-ua-compatible': 'IE=edge', 'Content-Language': 'en-nl', 'x-generator': 'Drupal 8 (https://www.drupal.org)', 'x-dns-prefetch-control': 'on', 'x-drupal-cache': 'MISS', 'Last-Modified': 'Mon, 22 Feb 2021 07:45:58 GMT', 'ETag': '"1613979958"', 'Content-Type': 'text/html; charset=UTF-8', 'x-acquia-host': 'www.ibm.com', 'x-acquia-path': '/nl-en', 'x-acquia-site': '', 'x-acquia-purge-tags': '', 'x-varnish': '626500481 628169331', 'x-cache-hits': '1', 'x-age': '844', 'Accept-Ranges': 'bytes', 'Content-Encoding': 'gzip', 'X-Akamai-Transformed': '9 - 0 pmb=mRUM,1', 'Cache-Control': 'public, max-age=300', 'Expires': 'Mon, 22 Feb 2021 19:08:24 GMT', 'Content-Length': '10447', 'Date': 'Mon, 22 Feb 2021 19:03:24 GMT', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'x-content-type-options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': 'upgrade-insecure-requests', 'Strict-Transport-Security': 'max-age=31536000', 'x-ibm-trace': 'www-dipatcher: dynamic rule'}

# %%
header['date']
# Out:
# 'Mon, 22 Feb 2021 19:03:24 GMT'

# %%
#Content-Type indicates the type of data:
header['Content-Type']
# Out:
# 'text/html; charset=UTF-8'

# %%
 r.encoding
# Out:
# 'UTF-8'

# %%
r.text[0:100]
# Out:
# '<!DOCTYPE html>\n<html lang="en-nl" dir="ltr">\n  <head>\n    <meta charset="utf-8" />\n<script>digitalD'

# %% [markdown]
# #Opening other URL types such as Images

# %%
url='https://static.escolakids.uol.com.br/2019/07/coala-alimentando-se.jpg'

# %%
r=requests.get(url)

# %%
print(r.headers)
# Out:
# {'Server': 'nginx', 'Date': 'Mon, 22 Feb 2021 19:10:07 GMT', 'Content-Type': 'image/jpeg', 'Content-Length': '82204', 'Connection': 'keep-alive', 'Last-Modified': 'Thu, 11 Jul 2019 11:40:41 GMT', 'ETag': '"5d272039-1411c"', 'Vary': 'Accept', 'X-Varnish': '884789084', 'Age': '0', 'Via': 'CacheUOL', 'X-Cache': 'MISS', 'Accept-Ranges': 'bytes'}

# %%
r.headers['Content-Type']
# Out:
# 'image/jpeg'

# %%
path=os.path.join(os.getcwd(),'image.png')
path
# Out:
# '/content/image.png'

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %%
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=830x500 at 0x7F9C69E99748>

# %% [markdown]
# TESTANDO VARIAÇÕES DO CODIGO ACIMA

# %%
import requests
import os 
from PIL import Image
from IPython.display import IFrame
url='https://static.escolakids.uol.com.br/2019/07/coala-alimentando-se.jpg'
r=requests.get(url)
r.headers['Content-Type']
path=os.path.join(os.getcwd(),'image.png')
path
with open(path,'wb') as f:
    f.write(r.content)
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=830x500 at 0x7F9C69E98C18>

# %%
# !wget -O /resources/data/Example1.txt https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt
# Out:
# /resources/data/Example1.txt: No such file or directory

# %%
import requests
import os 
from PIL import Image
from IPython.display import IFrame

# %%
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
header=r.headers
print(r.headers)
# Out:
# {'Date': 'Mon, 22 Feb 2021 19:34:07 GMT', 'X-Clv-Request-Id': '834a9bff-22c1-4953-a0c6-5ae6f9c9f1de', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': '834a9bff-22c1-4953-a0c6-5ae6f9c9f1de', 'ETag': '"522bc63a850f3569b8924c51131d5fe4"', 'Content-Type': 'text/plain', 'Last-Modified': 'Thu, 18 Feb 2021 20:45:18 GMT', 'Content-Length': '45'}

# %%
r.text[0:100]
# Out:
# 'This is line 1 \nThis is line 2\nThis is line 3'

# %% [markdown]
# # Get Request with URL Parameters

# %% [markdown]
# You can use the GET method to modify the results of your query, for example retrieving data from an API . We send a GET request to the server. Like before we have the Base URL, in the Route we append /get this indicates we would like to preform a GET request, this is demonstrated in the following table:

# %%
import requests
import os 
from PIL import Image
from IPython.display import IFrame
url_get='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/images/base_URL_Route.png'
r=requests.get(url)
path=os.path.join(os.getcwd(),'image.png')
path
with open(path,'wb') as f:
  f.write(r.content)
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1760x460 at 0x7F9C69045FD0>

# %%
url_get='http://httpbin.org/get'

# %%
#To create a Query string, add a dictionary. The keys are the parameter names, and the values are the value of the Query string.
payload={"name":"Joseph","ID":"123"}

# %%
r=requests.get(url_get,params=payload)

# %%
r.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=123'

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %%
print(r.status_code)
# Out:
# 200

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.23.0",
#     "X-Amzn-Trace-Id": "Root=1-603409ca-46f968cf778ffda07204d3e0"
#   },
#   "origin": "35.204.54.51",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.json()
# Out:
# {'args': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-603409ca-46f968cf778ffda07204d3e0'},
#  'origin': '35.204.54.51',
#  'url': 'http://httpbin.org/get?name=Joseph&ID=123'}

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# # Post Requests

# %% [markdown]
# Like a GET request a POST is used to send data to a server, but the POST request sends the data in a request body. In order to send the Post Request in Python in the URL we change the route to POST

# %%
url_post='http://httpbin.org/post'

# %% [markdown]
# This endpoint will expect data as a file or as a form, a form is convenient way to configure an HTTP request to send data to a server.
#
# To make a POST request we use the post() function, the variable payload is passed to the parameter  data :

# %%
r_post=requests.post(url_post,data=payload)

# %%
print("POST request URL:",r_post.url )
print("GET request URL:",r.url)
# Out:
# POST request URL: http://httpbin.org/post
# GET request URL: http://httpbin.org/get?name=Joseph&ID=123

# %%
print("POST request body:",r_post.request.body)
print("GET request body:",r.request.body)
# Out:
# POST request body: name=Joseph&ID=123
# GET request body: None

# %%
r_post.json()['form']
# Out:
# {'ID': '123', 'name': 'Joseph'}
