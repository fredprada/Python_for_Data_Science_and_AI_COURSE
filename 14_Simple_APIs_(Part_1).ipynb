# %% [markdown]
# <a href="https://colab.research.google.com/github/fredprada/Python_for_Data_Science_and_AI_COURSE/blob/main/14_Simple_APIs_(Part_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #What is an API?

# %%
import pandas as pd
dict_={'a':[11,21,31],'b':[12,22,32]}
df=pd.DataFrame(dict_)
df.head()
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %%
import pandas as pd
dict_={'a':[11,21,31],'b':[12,22,32]}
df=pd.DataFrame(dict_)
df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %% [markdown]
# #**REST API**
# #Allow to communicate with the internet
# #**RE**presentational **S**tate **T**ransfer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# it sends a request for a website using HTTP (as the API) and the website returns the Data requested.
# This flow uses an INPUT and it returns the OUTPUT.
